# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import norm
import pandas as pd
dataset = pd.read_csv('gaussdata.csv')
plt.title("Gaussian model")
domain=np.linspace(20,90,20)
plt.plot(domain,norm.pdf(domain,61.20,7.815),label="smokers")
domain=np.linspace(20,90,20)
plt.plot(domain,norm.pdf(domain,60.79,7.937),label="asthma")
domain=np.linspace(20,90,20)
plt.plot(domain,norm.pdf(domain,61.646,7.969),label="COPD")
domain=np.linspace(50,90,20)
plt.plot(domain,norm.pdf(domain,65.73,7.893),label="SAC",linewidth=3,linestyle=':')
domain=np.linspace(20,90,20)
plt.plot(domain,norm.pdf(domain,66.05,9.687),label="SA",linewidth=3,linestyle=':')
domain=np.linspace(20,90,20)
plt.plot(domain,norm.pdf(domain,62.53,8.805),label="SC",linewidth=3,linestyle=':')
domain=np.linspace(20,90,20)
plt.plot(domain,norm.pdf(domain,64.40,7.82),label="CA",linewidth=3,linestyle=':')
domain=np.linspace(20,90,20)
plt.plot(domain,norm.pdf(domain,55.61,6.68),label="HEALTHY",linewidth=5)
plt.xlabel("u_j*a")
plt.legend(loc='best')
plt.show()
plt.title("FOR HEALTHY")
domain1=np.linspace(20,90,20)
plt.plot(domain1,norm.pdf(domain1,54.52,6.550),label="chronological")
domain1=np.linspace(20,90,20)
plt.plot(domain1,norm.pdf(domain1,55.61,6.55),label="HEALTHY")
domain=np.linspace(50,90,20)
plt.legend(loc='best')
plt.show()
plt.title("for smokers")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,57.20,7.34),label="chronological")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,61.20,7.815),label="smokers")
domain=np.linspace(50,90,30)
plt.legend(loc='best')
plt.show()
plt.title("for asthma")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,55.77,7.28),label="chronological")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,60.79,7.937),label="asthma")
domain=np.linspace(50,90,30)
plt.legend(loc='best')
plt.show()
plt.title("for COPD")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,56.042,7.244),label="chronological")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,61.646,7.969),label="COPD")
domain=np.linspace(50,90,30)
plt.legend(loc='best')
plt.show()
plt.title("for SAC")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,55.24,6.633),label="chronological")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,65.73,7.893),label="SAC")
domain=np.linspace(50,90,30)
plt.legend(loc='best')
plt.show()
plt.title("for SA")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,56.94,8.348),label="chronological")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,66.05,9.687),label="SAC")
domain=np.linspace(50,90,30)
plt.legend(loc='best')
plt.show()
plt.title("for SC")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,55.83,7.86),label="chronological")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,62.53,8.805),label="SC")
domain=np.linspace(50,90,30)
plt.legend(loc='best')
plt.show()
plt.title("for CA")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,56.49,6.86),label="chronological")
domain1=np.linspace(20,90,30)
plt.plot(domain1,norm.pdf(domain1,64.40,7.82),label="CA")
domain=np.linspace(50,90,30)
plt.legend(loc='best')
plt.show()
