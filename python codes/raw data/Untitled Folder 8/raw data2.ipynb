# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_csv('rdata1.csv')
X1 = dataset.iloc[1:67, 0].values
X2 = dataset.iloc[1:67,1].values
plt.plot(X1, X2,label= "healthy",color="blue")
dataset = pd.read_csv('rdata2.csv')
Y1= dataset.iloc[1:67,0]
Y2= dataset.iloc[1:67,1]
plt.plot(Y1,Y2,color="red",label= "smokers")
plt.title('HEALTHY VS SMOKERS')
plt.xlabel('CHRONOLOGICAL AGE')
plt.ylabel('FEV MEASURES')
plt.show()
dataset = pd.read_csv('rdata1.csv')
X1 = dataset.iloc[1:67, 0].values
X2 = dataset.iloc[1:67,1].values
plt.plot(X1, X2,label= "healthy",color="blue")
dataset = pd.read_csv('rdata3.csv')
Y1= dataset.iloc[1:67,0]
Y2= dataset.iloc[1:67,1]
plt.plot(Y1,Y2,color="red",label= "asthma")
plt.title('HEALTHY VS ASTHMA')
plt.xlabel('CHRONOLOGICAL AGE')
plt.ylabel('FEV MEASURES')
plt.show()
dataset = pd.read_csv('rdata1.csv')
X1 = dataset.iloc[1:67, 0].values
X2 = dataset.iloc[1:67,1].values
plt.plot(X1, X2,label= "healthy",color="blue")
dataset = pd.read_csv('rdata6.csv')
Y1= dataset.iloc[1:67,0]
Y2= dataset.iloc[1:67,1]
plt.plot(Y1,Y2,color="red",label= "COPD")
plt.title('HEALTHY VS COPD')
plt.xlabel('CHRONOLOGICAL AGE')
plt.ylabel('FEV MEASURES')
plt.show()
dataset = pd.read_csv('rdata1.csv')
X1 = dataset.iloc[1:67, 0].values
X2 = dataset.iloc[1:67,1].values
plt.plot(X1, X2,label= "healthy",color="blue")
dataset = pd.read_csv('rdata5.csv')
Y1= dataset.iloc[1:67,0]
Y2= dataset.iloc[1:67,1]
plt.plot(Y1,Y2,color="red",label= "SAC")
plt.title('HEALTHY VS SAC')
plt.xlabel('CHRONOLOGICAL AGE')
plt.ylabel('FEV MEASURES')
plt.show()
dataset = pd.read_csv('rdata1.csv')
X1 = dataset.iloc[1:67, 0].values
X2 = dataset.iloc[1:67,1].values
plt.plot(X1, X2,label= "healthy",color="blue")
dataset = pd.read_csv('rdata4.csv')
Y1= dataset.iloc[1:67,0]
Y2= dataset.iloc[1:67,1]
plt.plot(Y1,Y2,color="red",label= "SA")
plt.title('HEALTHY VS SA')
plt.xlabel('CHRONOLOGICAL AGE')
plt.ylabel('FEV MEASURES')
plt.show()
dataset = pd.read_csv('rdata1.csv')
X1 = dataset.iloc[1:67, 0].values
X2 = dataset.iloc[1:67,1].values
plt.plot(X1, X2,label= "healthy",color="blue")
dataset = pd.read_csv('rdata7.csv')
Y1= dataset.iloc[1:67,0]
Y2= dataset.iloc[1:67,1]
plt.plot(Y1,Y2,color="red",label= "SC")
plt.title('HEALTHY VS SC')
plt.xlabel('CHRONOLOGICAL AGE')
plt.ylabel('FEV MEASURES')
plt.show()
dataset = pd.read_csv('rdata1.csv')
X1 = dataset.iloc[1:67, 0].values
X2 = dataset.iloc[1:67,1].values
plt.plot(X1, X2,label= "healthy",color="blue")
dataset = pd.read_csv('rdata8.csv')
Y1= dataset.iloc[1:67,0]
Y2= dataset.iloc[1:67,1]
plt.plot(Y1,Y2,color="red",label= "CA")
plt.title('HEALTHY VS CA')
plt.xlabel('CHRONOLOGICAL AGE')
plt.ylabel('FEV MEASURES')
plt.show()
